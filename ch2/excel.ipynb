# %% [markdown]
# pip : 파이썬 모듈이나 패키지를 쉽게 설치할 수 있도록 도와주는 도구
#
# 1. 패키지 설치
# pip install 패키지명
# pip install 패키지명==1.0.4
#
# 2. 패키지 업그레이드
# pip install --upgrade 패키지명
#
# 3. 패키지 제거
# pip uninstall 패키지명
#
# 4. 설치된 패키지 확인
# pip list
#
# pip install openpyxl : 엑셀파일 패키지
# pip install pillow : 이미지 패키지

# %%
from openpyxl import Workbook

wb = Workbook()   # 새 워크북 생성
ws = wb.active    # 현재 활성화된 sheet 가져옴

ws.title = "시트1"
wb.save("./resource/sample.xlsx")
wb.close()

# %%
# 시트 생성

ws1 = wb.create_sheet()
ws1.title = "시트2"
ws1.sheet_properties.tabColor = "ff66ff"

wb.save("./resource/sample.xlsx")

# %%
# index : 시트 위치 지정
ws1 = wb.create_sheet(title="급여명세",index=2)

# 시트 복사
new_ws = wb["시트2"] # 생성된 시트에 접근
new_ws["A1"] = "Test"
target = wb.copy_worksheet(new_ws)
target.title="Copied Sheet"

wb.save("./resource/sample.xlsx")

# %%
# 생성된 모든 시트명 가져오기
wb.sheetnames
# Out:
# ['시트1', '시트2', '급여명세', 'Copied Sheet']

# %%
ws1 = wb["시트1"]

# 셀에 데이터 입력
ws1["A1"] = 1
ws1["A2"] = 2
ws1["A3"] = 3
ws1["A4"] = 4

ws1["B1"] = 5
ws1["B2"] = 6
ws1["B3"] = 7
ws1["B4"] = 8

print(ws1["A1"])  # 셀 정보 출력
print(ws1["A1"].value)  # 셀 값 출력

print(ws1.cell(row=1, column=1).value) # A1
print(ws1.cell(row=2, column=2).value) # B2

w = ws1.cell(row=1, column=3, value=10)
print(w.value)

wb.save("./resource/sample.xlsx")
# Out:
# <Cell '시트1'.A1>
# 1
# 1
# 6
# 10

# %%
# 1~100 사이의 임의의 숫자를 채우기
from random import randint

wb = Workbook()   # 새 워크북 생성
ws = wb.active    # 현재 활성화된 sheet 가져옴

ws.title = "시트1"

for x in range(1, 11):
    for y in range(1, 11):
        ws.cell(row=x, column=y, value=randint(1,100))



wb.save("./resource/sample2.xlsx")
wb.close()

# %%
# excel 파일 열기

from openpyxl import load_workbook
wb = load_workbook("./resource/sample2.xlsx")

# 워크시트 가져오기
ws = wb.active

# 셀 내용 가져오기 - 행,열 개수 알고 있을 때
# for x in range(1, 11):
#     for y in range(1, 11):
#         print(ws.cell(row=x, column=y).value, end=" ")
#     print()

# max_row, max_column : 시트가 가지고 있는 행,열 개수 가져오기
for x in range(1, ws.max_row+1):
    for y in range(1, ws.max_column+1):
        print(ws.cell(row=x, column=y).value, end=" ")
    print()
# Out:
# 65 3 35 71 59 44 98 43 36 100
# 49 74 86 32 84 1 56 21 84 45
# 26 65 6 95 5 31 30 3 51 39
# 54 30 16 35 39 27 13 16 66 55
# 17 33 68 79 72 66 83 38 33 56
# 47 67 48 98 39 61 14 24 49 42
# 46 38 87 72 18 13 15 32 75 39
# 98 75 27 60 98 75 67 11 87 18
# 71 42 35 12 50 28 60 50 24 52
# 32 99 76 55 35 51 83 55 55 7

# %%
from openpyxl import Workbook
from random import randint

wb = Workbook()
ws = wb.active

# 행 삽입
ws.append(["번호","영어","수학"])

for i in range(1, 11):
    ws.append([i, randint(1,100), randint(1,100)])

# 컬럼 가져오기
# col_B = ws["B"]
# print(col_B)

# for cell in col_B:
#     print(cell.value)

# cols = ws["B:C"]
# for c in cols:
#     for cell in c:
#         print(cell.value, end=" ")
#     print()

# 행 가져오기
# row_title = ws[1]
# for cell in row_title:
#     print(cell.value)

# row_range = ws[2:ws.max_row]
# for rows in row_range:
#     for cell in rows:
#         print(cell.value, end=" ")
#     print()

# for row in tuple(ws.rows):
#     print(row[1].value)

# for col in tuple(ws.columns):
#     print(col[0].value)

# ws.iter_rows() : 전체 rows 가져오기
# ws.iter_rows(min_row=1,max_row=5,max_col=1) : 특정 범위의 rows,cols 가져오기
# for row in ws.iter_rows(min_row=1,max_row=5,max_col=1):
#     for cell in row:
#         print(cell.value, end=" ")
#     print()

for col in ws.iter_cols(min_row=1,max_row=5,max_col=2):
    for cell in col:
        print(cell.value, end=" ")
    print()

wb.save("./resource/range.xlsx")
# Out:
# 번호 1 2 3 4
# 영어 44 16 21 86

# %%
from openpyxl import load_workbook

# 읽어올 엑셀 파일 지정
wb = load_workbook("./resource/range.xlsx")

# 시트 가져오기
ws = wb.active

# for row in ws.iter_rows(min_row=2):
#     #print(row)
#     print(f"{row[0].value} 번 학생의 영어점수 {row[1].value}, 수학점수 {row[2].value}")


# 영어 점수가 70 점 이상인 학생의 영어 점수 출력
# 1번 학생의 영어점수는 75 점
for row in ws.iter_rows(min_row=2):
    if row[1].value >= 70: 
        print(f"{row[0].value} 번 학생의 영어점수 {row[1].value}")

# 영어 => 컴퓨터로 변경
for row in ws.iter_rows(max_row=1):
    for cell in row:
        if cell.value == "영어":
            cell.value = "컴퓨터"

wb.save("./resource/range.xlsx")
wb.close()
# Out:
# 6 번 학생의 영어점수 89
# 8 번 학생의 영어점수 97
# 9 번 학생의 영어점수 78

# %%
# 행,열 삽입
# 읽어올 엑셀 파일 지정
wb = load_workbook("./resource/range.xlsx")

# 시트 가져오기
ws = wb.active

# ws.insert_rows(8)
ws.insert_rows(8,5)  # 8번 위치부터 5줄 삽입

ws.insert_cols(2, 3)

wb.save("./resource/range.xlsx")
wb.close()

# %%
# 행, 열 삭제

# 읽어올 엑셀 파일 지정
wb = load_workbook("./resource/range.xlsx")

# 시트 가져오기
ws = wb.active

# ws.delete_rows(7)
# ws.delete_rows(4,3)
ws.delete_cols(2,2)

wb.save("./resource/range.xlsx")
wb.close()

# %%
# 셀 이동

wb = load_workbook("./resource/range.xlsx")
ws = wb.active

ws.move_range("B1:C11", rows=0, cols=1)
ws.cell(column=2,row=1).value = "국어"

wb.save("./resource/range.xlsx")
wb.close()

# %%
# 차트 작성
from openpyxl.chart import BarChart,LineChart,Reference

wb = load_workbook("./resource/range.xlsx")
ws = wb.active

# bar 차트 설정
bar_value = Reference(ws, min_row=2, max_row=11, min_col=2, max_col=3)
# 차트 종류 설정
bar_chart = BarChart() 
# 차트 데이터 추가
bar_chart.add_data(bar_value)
# 시트에 차트 추가
ws.add_chart(bar_chart,"E1")


# 라인 차트 설정
line_value = Reference(ws, min_row=1, max_row=11, min_col=2, max_col=3)
# 차트 종류 설정
line_chart = LineChart() 
# 차트 데이터 추가
line_chart.add_data(line_value, titles_from_data=True)
# 차트 상세 설정
line_chart.title = "성적표"
line_chart.style = 20
line_chart.y_axis.title = "점수"
line_chart.x_axis.title = "번호"

# 시트에 차트 추가
ws.add_chart(line_chart,"A16")

wb.save("./resource/range_chart.xlsx")
wb.close()

# %%
# 셀 서식
from openpyxl.styles import Font, Border, PatternFill, Alignment
from openpyxl.styles.borders import Side

wb = load_workbook("./resource/range.xlsx")
ws = wb.active

# 셀 너비 조절
ws.column_dimensions["A"].width = 5

# 행 높이 조절
ws.row_dimensions[1].height = 50

# 폰트 스타일
# 셀 선택
a1 = ws["A1"]
b1 = ws["B1"]
c1 = ws["C1"]

a1.font = Font(color="ff0000", italic=True, bold=True)
b1.font = Font(color="cc33ff", name="Arial", strike=True)
c1.font = Font(color="0000ff", size=20, underline="single")

# 테두리 객체 생성
thin_border = Border(left=Side(border_style="thin", color="00ffcc"), right=Side(border_style="thin"),
                      top=Side(border_style="double"), bottom=Side(border_style="double"))

# 셀에 테두리 적용
a1.border = thin_border
b1.border = thin_border
c1.border = thin_border

# 셀 배경색 
for row in ws.rows:
    for cell in row:

        # 셀정렬
        cell.alignment = Alignment(horizontal="center", vertical="center")

        if cell.column == 1:
            continue

        # isinstance() : 데이터 타입 확인    
        if isinstance(cell.value, int) and cell.value > 80:
            cell.fill = PatternFill(fgColor="00ff00", fill_type="solid")
            cell.font = Font(color="ff0000")


wb.save("./resource/range_style.xlsx")
wb.close()

# %%
from datetime import datetime

wb = Workbook()
ws = wb.active

ws["A1"] = datetime.today()
ws["A2"] = "=sum(1,2,3)"
ws["A3"] = "=average(1,2,3)"


ws["A4"] = 10
ws["A5"] = 20
ws["A6"] = 30
ws["A7"] = "=sum(A4:A6)"

wb.save("./resource/formula.xlsx")

# %%
# range.xlsx 
# average() 영어, 수학

wb = load_workbook("./resource/range.xlsx")
ws = wb.active

ws["B12"] = "=average(B2:B11)"
ws["C12"] = "=average(C2:C11)"

wb.save("./resource/range.xlsx")

# %%
# 수식이 들어간 셀 읽어오기

wb = load_workbook("./resource/formula.xlsx", data_only=True)
ws = wb.active

# 셀 값 모두 가져오기
for values in ws.values:
    for cell in values:
        print(cell)
# Out:
# 2024-05-21 11:34:06.745000
# None
# None
# 10
# 20
# 30
# None

# %%
# 셀 병합

wb = load_workbook("./resource/range.xlsx")
ws = wb.active

ws.merge_cells("D1:E1")
ws["D1"].value = "merge"

wb.save("./resource/merge.xlsx")

# %%
# 셀 병합 해제

wb = load_workbook("./resource/merge.xlsx")
ws = wb.active

ws.unmerge_cells("D1:E1")


wb.save("./resource/merge.xlsx")

# %%
# 이미지 삽입
from openpyxl.drawing.image import Image  # pillow 필요로 함 - 이미지 패키지

wb = Workbook()
ws = wb.active

# 이미지 객체 생성
img = Image("./resource/img.jpg")

# 시트에 이미지 추가
ws.add_image(img, "C3")


wb.save("./resource/image.xlsx")

# %% [markdown]
# - 성적 산출
# - 100점 만점을 기준으로 출석:10, 퀴즈1:10, 퀴즈2:10, 중간고사:20, 기말고사:30, 프로젝트:20
# - 학생들의 최종 성적을 검토하는 과정에서 퀴즈2 문제에 오류를 발견하여 모두 만점처리를 하기로 함
# - [최종 성적]
# - 학번, 출석, 퀴즈1, 퀴즈2, 중간고사, 기말고사, 프로젝트
# - 1, 10, 8, 5, 14, 26, 12
# - 2, 7, 3, 7, 15, 24, 18
# - 3, 9, 5, 8, 8, 12, 4
# - 4, 7, 8, 7, 17, 21, 18
# - 5, 7, 8, 7, 16, 25, 15
# - 6, 3, 5, 8, 8, 17, 0
# - 7, 4, 9, 10, 16, 27, 18
# - 8, 6, 6, 6, 15, 19, 17
# - 9, 10, 10, 9, 19, 30, 19
# - 10, 9, 8, 8, 20, 25, 20
#
#
# - 1. 퀴즈2 점수를 10으로 수정
# - 2. H열에 총점(sum 사용), I열에 성적 정보 추가
# - 3. 성적 정보 : 총점 90 이상 A, 80 이상 B, 70 이상 C, 나머지 D
# - 4. 출결이 5 미만인 경우 총점 상관없이 F
# - 5. 파일명 : scores.xlsx

# %%
from openpyxl import Workbook
wb = Workbook()

# 시트 가져오기
ws = wb.active

# 학생 점수 엑셀 저장

# 제목 행 추가
ws.append(["학번", "출석", "퀴즈1", "퀴즈2", "중간고사", "기말고사", "프로젝트"])

# 성적 데이터 추가
scores = [
    [1, 10, 8, 5, 14, 26, 12],
    [2, 7, 3, 7, 15, 24, 18],
    [3, 9, 5, 8, 8, 12, 4],
    [4, 7, 8, 7, 17, 21, 18],
    [5, 7, 8, 7, 16, 25, 15],
    [6, 3, 5, 8, 8, 17, 0],
    [7, 4, 9, 10, 16, 27, 18],
    [8, 6, 6, 6, 15, 19, 17],
    [9, 10, 10, 9, 19, 30, 19],   
    [10, 9, 8, 8, 20, 25, 20]
] 
for score in scores:
    ws.append(score)



wb.save("./resource/scores.xlsx")
wb.close()

# %%
wb = load_workbook("./resource/scores.xlsx")
ws = wb.active

# 퀴즈2 점수를 10으로 수정
# print(ws["D"])
for idx, cell in enumerate(ws["D"]):
    # print(idx, cell.value)
    if idx == 0:
        continue
    cell.value = 10

# H열에 총점(sum 사용), I열에 성적 정보 추가
# 제목 행 추가
ws["H1"].value = "총점"
ws["I1"].value = "성적"

for idx, score in enumerate(scores,start=2):
    # 리스트에서 기존 퀴즈2 점수는 제외하고 다시 수정된 10점 가산해서 총합 구하기
    total = sum(score[1:]) - score[3] + 10
    ws.cell(row=idx, column=8).value = "=sum(B{0}:G{0})".format(idx)

    # 성적 정보 : 총점 90 이상 A, 80 이상 B, 70 이상 C, 나머지 D
    grade = None
    if total >= 90:
        grade = "A"
    elif total >= 80:
        grade = "B"
    elif total >= 70:
        grade = "C"
    else:
        grade = "D"

    # 출결이 5 미만인 경우 총점 상관없이 F
    if score[1] < 5:
        grade = "F"

    ws.cell(row=idx, column=9).value = grade

wb.save("./resource/scores.xlsx")
wb.close()

# %%
# 총점 - 바차트(A13)
from openpyxl import load_workbook
from openpyxl.chart import BarChart,LineChart,Reference

wb = load_workbook("./resource/scores.xlsx", data_only=True)
ws = wb.active

# bar 차트 설정
bar_value = Reference(ws, min_row=2, max_row=11, min_col=8, max_col=8)
# 차트 종류 설정
bar_chart = BarChart() 
# 차트 데이터 추가
bar_chart.add_data(bar_value)
# 시트에 차트 추가
ws.add_chart(bar_chart,"A13")


wb.save("./resource/scores.xlsx")
wb.close()
